# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data1.csv")

# %%
df
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# 31               7.9  101302
# 32               8.2  113812
# 33               8.5  111620
# 34               8.7  109431
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
df.isna().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
x = df.drop("Salary",axis=1)

# %%
x
# Out:
#     Experience Years
# 0                1.1
# 1                1.2
# 2                1.3
# 3                1.5
# 4                2.0
# 5                2.2
# 6                2.5
# 7                2.9
# 8                3.0
# 9                3.2
# 10               3.2
# 11               3.5
# 12               3.7
# 13               3.8
# 14               3.9
# 15               4.0
# 16               4.0
# 17               4.1
# 18               4.3
# 19               4.5
# 20               4.7
# 21               4.9
# 22               5.1
# 23               5.3
# 24               5.5
# 25               5.9
# 26               6.0
# 27               6.2
# 28               6.5
# 29               6.8
# 30               7.1
# 31               7.9
# 32               8.2
# 33               8.5
# 34               8.7
# 35               9.0
# 36               9.5
# 37               9.6
# 38              10.3
# 39              10.5

# %%
y = df["Experience Years"]

# %%
y
# Out:
# 0      1.1
# 1      1.2
# 2      1.3
# 3      1.5
# 4      2.0
# 5      2.2
# 6      2.5
# 7      2.9
# 8      3.0
# 9      3.2
# 10     3.2
# 11     3.5
# 12     3.7
# 13     3.8
# 14     3.9
# 15     4.0
# 16     4.0
# 17     4.1
# 18     4.3
# 19     4.5
# 20     4.7
# 21     4.9
# 22     5.1
# 23     5.3
# 24     5.5
# 25     5.9
# 26     6.0
# 27     6.2
# 28     6.5
# 29     6.8
# 30     7.1
# 31     7.9
# 32     8.2
# 33     8.5
# 34     8.7
# 35     9.0
# 36     9.5
# 37     9.6
# 38    10.3
# 39    10.5
# Name: Experience Years, dtype: float64

# %%
x_train,y_train,x_test,y_test = train_test_split(x,y, test_size = 0.2)

# %%
x_train
# Out:
#     Experience Years
# 22               5.1
# 9                3.2
# 32               8.2
# 12               3.7
# 20               4.7
# 0                1.1
# 28               6.5
# 36               9.5
# 34               8.7
# 30               7.1
# 18               4.3
# 17               4.1
# 21               4.9
# 6                2.5
# 15               4.0
# 23               5.3
# 3                1.5
# 33               8.5
# 27               6.2
# 31               7.9
# 5                2.2
# 29               6.8
# 38              10.3
# 24               5.5
# 35               9.0
# 2                1.3
# 11               3.5
# 8                3.0
# 1                1.2
# 10               3.2
# 19               4.5
# 14               3.9

# %%
x_test
# Out:
# 22     5.1
# 9      3.2
# 32     8.2
# 12     3.7
# 20     4.7
# 0      1.1
# 28     6.5
# 36     9.5
# 34     8.7
# 30     7.1
# 18     4.3
# 17     4.1
# 21     4.9
# 6      2.5
# 15     4.0
# 23     5.3
# 3      1.5
# 33     8.5
# 27     6.2
# 31     7.9
# 5      2.2
# 29     6.8
# 38    10.3
# 24     5.5
# 35     9.0
# 2      1.3
# 11     3.5
# 8      3.0
# 1      1.2
# 10     3.2
# 19     4.5
# 14     3.9
# Name: Experience Years, dtype: float64

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,x_test)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import  r2_score

# %%
r2_score(x_train,x_test)
# Out:
# 1.0

# %%
y_pred = lr.predict(y_train)

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
sns.regplot(x=x,y=y,data=df,color='r')
# Out:
# <Axes: xlabel='Experience Years', ylabel='Experience Years'>
