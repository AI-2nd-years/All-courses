# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("./data1.csv")

# %%
df
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# 31               7.9  101302
# 32               8.2  113812
# 33               8.5  111620
# 34               8.7  109431
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
df.isna().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
x = df[["Experience Years"]]

# %%
y = df.Salary

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
y_test
# Out:
# 32    113812
# 20     64500
# 36    116969
# 4      43525
# 14     63218
# 21     67938
# 5      39891
# 1      42774
# Name: Salary, dtype: int64

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9527571891660215

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_train,y_train)

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse = mean_squared_error(y_pred,y_test)

# %%
mse
# Out:
# 31499598.710383996

# %%
lr.score(x_test,y_test)
# Out:
# 0.9615155337503677

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9531319220327282

# %%
import seaborn as sns

# %%
sns.regplot(x = x_test,y=y_test)
# Out:
# <Axes: xlabel='Experience Years', ylabel='Salary'>

# %%
lr.coef_
# Out:
# array([9339.96463985])

# %%
lr.intercept_
# Out:
# np.float64(26687.312298276694)

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd_reg = SGDRegressor(learning_rate="constant",max_iter=1000,loss="squared_error")

# %%
sgd_reg.fit(x_train,y_train)
# Out:
# SGDRegressor(learning_rate='constant')

# %%
y_pred=sgd_reg.predict(x_test)

# %%
print(f"W: {sgd_reg.coef_[0]:.4f}, W0: {sgd_reg.intercept_[0]:.4f}")
# Out:
# W: 10371.9975, W0: 23088.4963

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9649891623527188
